# %% [markdown]
# # Project: Analyzing Macbeth

# %% [markdown]
# ## Introduction
# For our first day and first data science project, we're going to do some rudimentry analysis of Shakespeare's classic play: Macbeth! You will get practice working with lists, condtionals and dictionaries, visualizing data, and thinking analytically about data.

# %% [markdown]
# ## Objectives
# You will be able to:
# * Show mastery of the content covered in this section

# %% [markdown]
# ### Getting the Data
# Here we start by importing a python package and using it to pull the transcript of Macbeth from the project Gutenberg website. We also preview a few details about what is now stored in the variable macbeth; it's a string with 119,846 characters, the first 500 of which are printed below.

# %%
import requests
macbeth = requests.get('http://www.gutenberg.org/cache/epub/2264/pg2264.txt').text

print(type(macbeth))
print(len(macbeth))
print(macbeth[:500])
# Out:
# <class 'str'>
# 119846
# ﻿***The Project Gutenberg's Etext of Shakespeare's First Folio***
# ********************The Tragedie of Macbeth*********************
#
# This is our 3rd edition of most of these plays.  See the index.
#
#
# Copyright laws are changing all over the world, be sure to check
# the copyright laws for your country before posting these files!!
#
# Please take a look at the important information in this header.
# We encourage you to keep this file on your own disk, keeping an
# electronic path open for the nex

# %% [markdown]
# ### Your Task
#
# Your task is to create a bar graph of the 25 most common words in the Shakespeare's Macbeth.
#
#
# A common python programming pattern to counting objects, produce histograms, or update statistics is to make calls to a dictionary as you iterate through a list. For example, given a list of words, you can create a dictionary to store counts and then iterate through the list of words, checking how many times each word has appeared using your dictionary, and updating the dictionary count now that you've seen that word again. The `dictionary.get()` method is very useful in doing this. Read the docstring for the dictionary.get() method and use it along with the pseudocode above to create a bar graph of the 25 most common words from the transcript of Macbeth which has been loaded into a variable 'Macbeth'. Be sure to include a title and appropriate labels for your graph.

# %%
# Your code here

# Pseudo-code Outline
# Split the transcript into words
# Create a dictionary
# Iterate through the text of Macbeth
# Update word counts
# Create Bar Graph
# Include descriptive titles and labels

# %% [markdown]
# # New code Starts Hereeeeee:

# %%
# Split the transcript into words
macbeth_words = macbeth.split()
len(macbeth_words)
#macbeth_words[:200]
# Out:
# 20347

# %%
# Create a dictionary
    #macbeth_words_dist = dict(zip(macbeth_words, macbeth_words))
    #len(macbeth_words_dist)
    #type(macbeth_words_dist)
    #macbeth_words_dist

## Get number of unique words
num_words = len(list(set(macbeth_words)))
#num_words

macbeth_words_dict = dict( zip( list(set(macbeth_words)), [0] * num_words ) )
#len(macbeth_words_dict)
macbeth_words_dict
# Out:
# {'Demand': 0,
#  'seuen': 0,
#  'Cases,': 0,
#  'eare.': 0,
#  'Neptunes': 0,
#  'fighting.': 0,
#  'direfull': 0,
#  'Meeting': 0,
#  'Art': 0,
#  'Angels': 0,
#  'Witchcraft': 0,
#  'What,': 0,
#  'commend': 0,
#  'there.': 0,
#  'quell': 0,
#  'require': 0,
#  'sweeter': 0,
#  'There': 0,
#  '&': 0,
#  'Performe': 0,
#  'Whole': 0,
#  'brother?': 0,
#  'fairer': 0,
#  'periodic)': 0,
#  'Warre': 0,
#  'dare': 0,
#  'murky.': 0,
#  'Whispers': 0,
#  'What': 0,
#  'mget': 0,
#  'thousands.': 0,
#  'Dogs,': 0,
#  'plays.': 0,
#  'users.': 0,
#  'Churches:': 0,
#  'conceiue,': 0,
#  'meane?': 0,
#  "stay'd": 0,
#  'estate': 0,
#  'Temple-haunting': 0,
#  'Scoena': 0,
#  'Seywards': 0,
#  "for't.": 0,
#  'can': 0,
#  'eyes?': 0,
#  'together?': 0,
#  'owe': 0,
#  'wooingly': 0,
#  'further,': 0,
#  'production,': 0,
#  'Feuer,': 0,
#  'High': 0,
#  'funding;': 0,
#  'lyes': 0,
#  'Flowers': 0,
#  'within.': 0,
#  'sleeping,': 0,
#  'call.': 0,
#  "there's": 0,
#  'author': 0,
#  'ore-leapes': 0,
#  'keene': 0,
#  'day?': 0,
#  'offended:': 0,
#  'Assassination': 0,
#  'timely': 0,
#  'rarer': 0,
#  'be': 0,
#  "Prey's": 0,
#  'rightly': 0,
#  'where': 0,
#  'Trifles,': 0,
#  'Seruants': 0,
#  'caveat.': 0,
#  'meeke;': 0,
#  'bound': 0,
#  'prouokes': 0,
#  'drops': 0,
#  'leauy': 0,
#  'Syue': 0,
#  'taught,': 0,
#  'name?': 0,
#  'Nay,': 0,
#  'accust,': 0,
#  'aduantage': 0,
#  'Their': 0,
#  'Venom': 0,
#  'bed,': 0,
#  'paines,': 0,
#  "Master's": 0,
#  'continue': 0,
#  'browser': 0,
#  'wastfull': 0,
#  'MAY': 0,
#  'Letters': 0,
#  'preserue': 0,
#  'rellish': 0,
#  'Moone': 0,
#  'ouerthrowne': 0,
#  "Turn'd": 0,
#  'concerne': 0,
#  'Strangers': 0,
#  'House?': 0,
#  'Gorgon.': 0,
#  'Drum': 0,
#  'Blinde-wormes': 0,
#  'Imaginings:': 0,
#  'Comes': 0,
#  'works.': 0,
#  'Say,': 0,
#  'Murther,': 0,
#  'Ecclipse:': 0,
#  'Primus.': 0,
#  'Brest,': 0,
#  'Hearts,': 0,
#  'Childhood,': 0,
#  'States,': 0,
#  'words': 0,
#  'etext': 0,
#  'noyse': 0,
#  'contributions': 0,
#  'well,': 0,
#  'password:': 0,
#  'signe,': 0,
#  'pace': 0,
#  'And': 0,
#  'thanks': 0,
#  'yellow': 0,
#  'those': 0,
#  '********************The': 0,
#  'care:': 0,
#  'endure': 0,
#  'Pertaines': 0,
#  'plain': 0,
#  'speech,': 0,
#  'distance': 0,
#  'Summer,': 0,
#  'Verity,': 0,
#  'woman;': 0,
#  "chanc'd:": 0,
#  'links;': 0,
#  'swolne': 0,
#  'thou,': 0,
#  'According': 0,
#  'Coward': 0,
#  'Wise,': 0,
#  'wife:': 0,
#  'haunt': 0,
#  'property': 0,
#  'runs': 0,
#  'Vsing': 0,
#  'Conspirers': 0,
#  'viewing': 0,
#  'Wake': 0,
#  'yong,': 0,
#  'This': 0,
#  'Make': 0,
#  'mee': 0,
#  'cheekes': 0,
#  'Largesse': 0,
#  'INDEMNITY': 0,
#  "Cow'd": 0,
#  'away': 0,
#  'wants': 0,
#  'poorely': 0,
#  'graue': 0,
#  'Darknesse': 0,
#  'nine': 0,
#  'vp': 0,
#  'year.': 0,
#  'verities': 0,
#  'right:': 0,
#  'Diuine,': 0,
#  'may': 0,
#  'POSSIBILITY': 0,
#  'Lords': 0,
#  'corporall': 0,
#  'Seemes': 0,
#  '[xxxxx10x.xxx]': 0,
#  'Rankes,': 0,
#  'stealthy': 0,
#  'Lady,': 0,
#  '*These': 0,
#  'ye': 0,
#  'Madam': 0,
#  'vntill': 0,
#  'Maggot': 0,
#  'content': 0,
#  'indeed': 0,
#  'Worlds': 0,
#  'chiefe': 0,
#  'Battlements': 0,
#  'set': 0,
#  "charg'd": 0,
#  'Custome:': 0,
#  'Consider': 0,
#  'Hart,': 0,
#  'Thriftlesse': 0,
#  'Feast,': 0,
#  'Michael': 0,
#  'This,': 0,
#  'dead': 0,
#  'running': 0,
#  'we,': 0,
#  'Norwayes': 0,
#  'Image:': 0,
#  'distribution': 0,
#  'Water-Rugs,': 0,
#  'also': 0,
#  'making:': 0,
#  'true?': 0,
#  'True,': 0,
#  'Children': 0,
#  'doing': 0,
#  'is.': 0,
#  'Kinsmen,': 0,
#  'Heark,': 0,
#  'Traueller': 0,
#  "Ditch-deliuer'd": 0,
#  'son': 0,
#  'eate': 0,
#  'strooke': 0,
#  'drinke,': 0,
#  'pale,': 0,
#  'what': 0,
#  'So': 0,
#  'weightie': 0,
#  'asleepe:': 0,
#  'Colmekill,': 0,
#  "vpon't,": 0,
#  "Nought's": 0,
#  'him;': 0,
#  'given': 0,
#  'any': 0,
#  'data,': 0,
#  'Butcher,': 0,
#  'read': 0,
#  'neyther': 0,
#  'Against': 0,
#  'hard': 0,
#  'solicites': 0,
#  'inuite,': 0,
#  'imperfect': 0,
#  'hands': 0,
#  'variety': 0,
#  'rid': 0,
#  'bad': 0,
#  "make's": 0,
#  "ha's?": 0,
#  'out': 0,
#  'One': 0,
#  'heere:': 0,
#  'sort': 0,
#  'which,': 0,
#  'Army,': 0,
#  'eye': 0,
#  'Fye,': 0,
#  'cleane?': 0,
#  'Despite': 0,
#  'At': 0,
#  'like': 0,
#  'keepes': 0,
#  'doe?': 0,
#  'Macduffe,': 0,
#  'cries': 0,
#  'software,': 0,
#  'supplyes': 0,
#  'file:': 0,
#  'legally': 0,
#  'tels': 0,
#  "awak'd": 0,
#  'broad,': 0,
#  'Feasts,': 0,
#  "Thou'lt": 0,
#  'expends': 0,
#  'happy': 0,
#  'Out-run': 0,
#  'liue,': 0,
#  'copy': 0,
#  'Malcolme,': 0,
#  'implied': 0,
#  'sences': 0,
#  'report': 0,
#  'performe': 0,
#  'hell': 0,
#  'Peale,': 0,
#  'Supper.': 0,
#  'MONEY': 0,
#  'please': 0,
#  'sight,': 0,
#  'cleaue': 0,
#  'traines,': 0,
#  'Hoast,': 0,
#  'thou?': 0,
#  'filling': 0,
#  'Epicures,': 0,
#  'Feat.': 0,
#  'further.': 0,
#  '[Etext': 0,
#  'Royalty': 0,
#  'Powres': 0,
#  'lacke': 0,
#  'present': 0,
#  'domain': 0,
#  'Venture': 0,
#  'Know,': 0,
#  'Greyhounds,': 0,
#  'trying': 0,
#  'brought': 0,
#  'calculate': 0,
#  'quit': 0,
#  'Acting': 0,
#  'touch.': 0,
#  'Threescore': 0,
#  'spoke,': 0,
#  'fresh': 0,
#  "vap'rous": 0,
#  'did:': 0,
#  'population,': 0,
#  "smoak'd": 0,
#  'indicate': 0,
#  'will.': 0,
#  'Ha,': 0,
#  'Everything': 0,
#  'House:': 0,
#  'held': 0,
#  'sprights,': 0,
#  'Drumme': 0,
#  'blames': 0,
#  'proud,': 0,
#  'wayes': 0,
#  'Wisdome,': 0,
#  'assaileable,': 0,
#  'Scale': 0,
#  'Hircan': 0,
#  'worthy': 0,
#  'chance': 0,
#  '"Defects".': 0,
#  'Fleans,': 0,
#  'smeare': 0,
#  'contacting': 0,
#  'Heart': 0,
#  'Shakes': 0,
#  'woe,': 0,
#  'troubled': 0,
#  'rauishing': 0,
#  'That': 0,
#  'Gulfe': 0,
#  'Stablenesse,': 0,
#  'againe?': 0,
#  'guild': 0,
#  'wayle': 0,
#  'Beare,': 0,
#  'After': 0,
#  'Disasters,': 0,
#  'purposes': 0,
#  'fitfull': 0,
#  'UNDER': 0,
#  "Shee'le": 0,
#  'others': 0,
#  'piece': 0,
#  'States': 0,
#  'Holy': 0,
#  'Example': 0,
#  'Beauteous,': 0,
#  'Takes': 0,
#  'large': 0,
#  'clutch': 0,
#  "mark'd": 0,
#  'multitudinous': 0,
#  'free:': 0,
#  "'Gainst": 0,
#  'Mankinde': 0,
#  '"cliche".': 0,
#  'meane:': 0,
#  'Heere,': 0,
#  'durst': 0,
#  'Dames': 0,
#  'cryes,': 0,
#  "arriu'd": 0,
#  'several': 0,
#  'Who,': 0,
#  'dread': 0,
#  'perfect': 0,
#  'composition:': 0,
#  'Soris?': 0,
#  'on,': 0,
#  'paid': 0,
#  '"public': 0,
#  'hypertext': 0,
#  'Ingratitude': 0,
#  'worst': 0,
#  'knowings': 0,
#  '2001.': 0,
#  'done.': 0,
#  'sorely': 0,
#  'PUBLIC': 0,
#  'part?': 0,
#  'M.': 0,
#  'greefe': 0,
#  'close': 0,
#  'angry': 0,
#  'Farrow:': 0,
#  '"AS-IS".': 0,
#  'Vice': 0,
#  'sometime,': 0,
#  'Deny': 0,
#  'Light,': 0,
#  'voyce': 0,
#  'aye': 0,
#  'Syw.': 0,
#  'Norway': 0,
#  'particulars': 0,
#  'Murtherers.': 0,
#  'Signifying': 0,
#  'Vprore': 0,
#  'Barnardo.': 0,
#  'owne': 0,
#  'Lid:': 0,
#  'Attend': 0,
#  'Doctor.': 0,
#  'dead,': 0,
#  'Mile': 0,
#  'PUNITIVE': 0,
#  'Wherefore': 0,
#  'failed]': 0,
#  'Witches,': 0,
#  'Spightfull,': 0,
#  'efforts,': 0,
#  'Hell-broth,': 0,
#  'againe:': 0,
#  'Trust.': 0,
#  "fayl'd": 0,
#  'cling': 0,
#  'paine:': 0,
#  'hold': 0,
#  'vs?': 0,
#  'stirring?': 0,
#  'Before': 0,
#  'Prince': 0,
#  'Graces': 0,
#  'harts': 0,
#  'powre': 0,
#  '[3]': 0,
#  'Graces,': 0,
#  'choake': 0,
#  'as': 0,
#  'Fume,': 0,
#  "prepar'd.": 0,
#  'poure': 0,
#  'sight?': 0,
#  'effects': 0,
#  'conjoined': 0,
#  'virus,': 0,
#  'Front,': 0,
#  '.set': 0,
#  "ow'd,": 0,
#  'digestion': 0,
#  '"w"\'s,': 0,
#  'Trumpet': 0,
#  'Childe.': 0,
#  'Braggart': 0,
#  'come.': 0,
#  'LIABILITY,': 0,
#  'Professe,': 0,
#  'Drinke,': 0,
#  'safetie.': 0,
#  'came': 0,
#  '[to': 0,
#  'hideous': 0,
#  'liue': 0,
#  'him.': 0,
#  'mine': 0,
#  'flattering': 0,
#  'vpon': 0,
#  'winde.': 0,
#  'Walke.': 0,
#  'So.': 0,
#  'Homage,': 0,
#  'burne': 0,
#  'bleed': 0,
#  'Who': 0,
#  'distance,': 0,
#  'Theefe': 0,
#  'Accounted': 0,
#  'Murderer.': 0,
#  'guilt': 0,
#  'stone,': 0,
#  'strangers': 0,
#  'nor': 0,
#  'loued': 0,
#  'Rancours': 0,
#  'vnsure': 0,
#  'later': 0,
#  'intent,': 0,
#  'Wine': 0,
#  "for't": 0,
#  'black': 0,
#  'Those': 0,
#  'horrid': 0,
#  'Attendants.': 0,
#  'Father?': 0,
#  'Of': 0,
#  'Lad.': 0,
#  'Messenger': 0,
#  'enough:': 0,
#  'Arme,': 0,
#  'Giuen': 0,
#  'Fortitude,': 0,
#  'ouer-bold,': 0,
#  'I:': 0,
#  'Cousins,': 0,
#  'burne,': 0,
#  'thinke,': 0,
#  "S's": 0,
#  'cleare:': 0,
#  'Scone.': 0,
#  'slab.': 0,
#  'Hand:': 0,
#  'shalt': 0,
#  'Spirits': 0,
#  '**Etexts': 0,
#  '(well': 0,
#  'changes,': 0,
#  'Hostesse.': 0,
#  'Destinie.': 0,
#  '100,000,000': 0,
#  'Tyranny:': 0,
#  'sutes': 0,
#  'STRICT': 0,
#  'Peace': 0,
#  'Began': 0,
#  "inform'd": 0,
#  'Forrest,': 0,
#  'quickly': 0,
#  'edition.': 0,
#  'DOMAIN': 0,
#  "vs'd": 0,
#  'Already': 0,
#  'Neither': 0,
#  'grow,': 0,
#  '[1]': 0,
#  'furious,': 0,
#  'Minde': 0,
#  'smacking': 0,
#  'Lye': 0,
#  'Crowne,': 0,
#  'thankes': 0,
#  'top-full': 0,
#  'Poyson,': 0,
#  'meane,': 0,
#  'alowd': 0,
#  'Donal.': 0,
#  'harrold': 0,
#  'Craues': 0,
#  'rather': 0,
#  'PRINT!': 0,
#  'prairienet.org,': 0,
#  'Sisters:': 0,
#  'Deuill': 0,
#  'witnest': 0,
#  'Blacke': 0,
#  'Wayting': 0,
#  'troubles:': 0,
#  "is't": 0,
#  'Faces': 0,
#  'vp:': 0,
#  'Iewels,': 0,
#  'WHAT': 0,
#  'cost': 0,
#  'extreme': 0,
#  "talk'st?": 0,
#  'Braine?': 0,
#  'Banquo.': 0,
#  'sighes,': 0,
#  'auoyded': 0,
#  'withall:': 0,
#  'Chance': 0,
#  'age,': 0,
#  'Macduffe.': 0,
#  'Watch,': 0,
#  'Lees': 0,
#  'recommends': 0,
#  'Day.': 0,
#  'mile:': 0,
#  'own': 0,
#  'Rosse.': 0,
#  'Northumberland,': 0,
#  'shade,': 0,
#  'clipt': 0,
#  'ill?': 0,
#  'resembled': 0,
#  'pit': 0,
#  "ne're": 0,
#  'Meet': 0,
#  'How': 0,
#  'Into': 0,
#  'withall': 0,
#  'whose': 0,
#  'Dunsinane': 0,
#  'Instruments': 0,
#  'here:': 0,
#  'Blessing,': 0,
#  'fly': 0,
#  'path': 0,
#  'houre:': 0,
#  'Commencing': 0,
#  'finger': 0,
#  'repent': 0,
#  'howle,': 0,
#  'pleasant': 0,
#  'Leade': 0,
#  "speak'st": 0,
#  'hat': 0,
#  'happyer': 0,
#  'Seruants;': 0,
#  'goodnight': 0,
#  'Shake': 0,
#  'cures,': 0,
#  'intended': 0,
#  'rest?': 0,
#  'pole,': 0,
#  'Fee-griefe': 0,
#  'twice': 0,
#  'death;': 0,
#  'bend': 0,
#  'Lord,': 0,
#  'Wisedome': 0,
#  '"small': 0,
#  'Goes': 0,
#  'Mawes': 0,
#  'stooles.': 0,
#  'Physitian:': 0,
#  'Trees': 0,
#  'saide': 0,
#  'Eagles;': 0,
#  'Patch?': 0,
#  'included.': 0,
#  'moue': 0,
#  'afraid': 0,
#  'loue': 0,
#  "deny't.": 0,
#  'countenance': 0,
#  'fought': 0,
#  'much:': 0,
#  "ly'st": 0,
#  'devised': 0,
#  'seeking': 0,
#  'same': 0,
#  'Mess.': 0,
#  'run.': 0,
#  'Braine': 0,
#  'pretend?': 0,
#  'ae.': 0,
#  'feare.': 0,
#  'nearly': 0,
#  'Court?': 0,
#  'Traitor': 0,
#  'Soule,': 0,
#  'Father': 0,
#  'damages,': 0,
#  'Coigne': 0,
#  'Mortalitie:': 0,
#  'yet': 0,
#  'broke': 0,
#  'stopt': 0,
#  'Horse:': 0,
#  'click,': 0,
#  'slope': 0,
#  'sorryest': 0,
#  'David': 0,
#  'users,': 0,
#  'substances,': 0,
#  'Weale:': 0,
#  'defect,': 0,
#  'notes': 0,
#  'there?': 0,
#  'Had': 0,
#  'an': 0,
#  'bathe': 0,
#  'heat': 0,
#  'ignorant': 0,
#  'Neuer': 0,
#  'Battell.': 0,
#  'empty': 0,
#  'Mal.': 0,
#  'Remorse,': 0,
#  'Scruples,': 0,
#  'seeme': 0,
#  'wayes:': 0,
#  'chafes,': 0,
#  'begge': 0,
#  'pricking': 0,
#  "'twer": 0,
#  'true': 0,
#  'of.': 0,
#  'easie.': 0,
#  'Act': 0,
#  'Soundly': 0,
#  'Confusion': 0,
#  'yeeld': 0,
#  'wrencht': 0,
#  'Sing': 0,
#  'gaue': 0,
#  'grace': 0,
#  'Particular': 0,
#  'Thoughts': 0,
#  'dir': 0,
#  'Hill': 0,
#  '-': 0,
#  'sinkes': 0,
#  'subtle,': 0,
#  'vnlineall': 0,
#  'Boughes.': 0,
#  'prepared': 0,
#  'Mother,': 0,
#  'Erre': 0,
#  'powrefull': 0,
#  'Rest': 0,
#  'beare': 0,
#  'Noblenesse,': 0,
#  'Kings': 0,
#  'cut': 0,
#  'practice': 0,
#  'goal': 0,
#  "obseru'd": 0,
#  'Carnegie-': 0,
#  "King's": 0,
#  'Hye': 0,
#  'herein:': 0,
#  'did,': 0,
#  'Summers': 0,
#  "kind'st": 0,
#  'regard': 0,
#  'health': 0,
#  'laue': 0,
#  'rise': 0,
#  'Lust,': 0,
#  'Vntimely': 0,
#  'behold:': 0,
#  'hours': 0,
#  'peace': 0,
#  'Closset,': 0,
#  'analyzed,': 0,
#  'Liege,': 0,
#  'flowne': 0,
#  "dy'de": 0,
#  'enjoy': 0,
#  'Fiend-like': 0,
#  'profits': 0,
#  'manner.': 0,
#  'ae': 0,
#  'Could': 0,
#  'Gummes,': 0,
#  'Marble,': 0,
#  'darefull,': 0,
#  'Starres,': 0,
#  'arbitrate,': 0,
#  'profound,': 0,
#  'have': 0,
#  'Vnkle': 0,
#  'meanes': 0,
#  'doubly': 0,
#  'subiect': 0,
#  'that:': 0,
#  'Not': 0,
#  'weyward': 0,
#  'Didst': 0,
#  'deerest': 0,
#  'new': 0,
#  'Knocking': 0,
#  'Doubtfull': 0,
#  "Can'st": 0,
#  '***The': 0,
#  'Seyton,': 0,
#  'worth,': 0,
#  'Temple,': 0,
#  'Hayle': 0,
#  'light': 0,
#  'Light?': 0,
#  'ill:': 0,
#  'swells:': 0,
#  'statement': 0,
#  'euer': 0,
#  'Barlet': 0,
#  'Maiestie?': 0,
#  "may'st": 0,
#  'giues': 0,
#  'Bloody,': 0,
#  'dauntlesse': 0,
#  'warranties': 0,
#  'Sent': 0,
#  'defective': 0,
#  'domestique,': 0,
#  'cloud,': 0,
#  'vnaccompanied,': 0,
#  'Geese': 0,
#  'who': 0,
#  'Treatise': 0,
#  "'twould": 0,
#  'anon': 0,
#  'speake,': 0,
#  'Beetle,': 0,
#  'session:': 0,
#  'WARRANTIES': 0,
#  'swelling': 0,
#  'been': 0,
#  'Passion,': 0,
#  'Honors,': 0,
#  'Actus': 0,
#  'mirrors': 0,
#  'Lookes,': 0,
#  'him:': 0,
#  'Cosin': 0,
#  'open:': 0,
#  'abroad:': 0,
#  'safely': 0,
#  'Foggy': 0,
#  'almost': 0,
#  'worse': 0,
#  "could'st": 0,
#  'stoole': 0,
#  'pine': 0,
#  'mould,': 0,
#  'afternoone?': 0,
#  'Shipwracking': 0,
#  "fear'd.": 0,
#  'hit.': 0,
#  'costs': 0,
#  'dare,': 0,
#  "brew'd": 0,
#  'alternatively': 0,
#  'Dunsinane.': 0,
#  'Yes,': 0,
#  'blacke,': 0,
#  'more,': 0,
#  'Rosse': 0,
#  'Eyes.': 0,
#  'Fiffe,': 0,
#  'Peeres': 0,
#  'fauor,': 0,
#  'Space': 0,
#  'within': 0,
#  'Addage': 0,
#  'saw,': 0,
#  'Snake,': 0,
#  'Notes:': 0,
#  'woman': 0,
#  'vertue,': 0,
#  'Whom': 0,
#  'print!"': 0,
#  'once.': 0,
#  'by': 0,
#  'hearty': 0,
#  'hisse': 0,
#  'REMEDIES': 0,
#  'solemne': 0,
#  'stopt,': 0,
#  'prouoker': 0,
#  'stand': 0,
#  'wicked': 0,
#  'speech:': 0,
#  'Gin': 0,
#  'gate:': 0,
#  'Grace.': 0,
#  'Gouts': 0,
#  'Disease': 0,
#  "Project's": 0,
#  'THE': 0,
#  'Quarry': 0,
#  'pale:': 0,
#  "Med'cines": 0,
#  'Sleep': 0,
#  'Cooz,': 0,
#  'day': 0,
#  'selection': 0,
#  'See': 0,
#  '2000+': 0,
#  'reading': 0,
#  'together,': 0,
#  'hurt': 0,
#  'hands:': 0,
#  'strangely': 0,
#  'changed': 0,
#  'Another': 0,
#  'Meete': 0,
#  'grant': 0,
#  'steales': 0,
#  "watch'd": 0,
#  'charge': 0,
#  'doe': 0,
#  "confirm'd": 0,
#  'A': 0,
#  "Promis'd": 0,
#  'roote': 0,
#  'But': 0,
#  'leysure,': 0,
#  'incarnardine,': 0,
#  'Was': 0,
#  'rowse.': 0,
#  'Warders': 0,
#  'Adde': 0,
#  'Witch,': 0,
#  'entrance:': 0,
#  'Mindes': 0,
#  'selfe-comparisons,': 0,
#  'Stay': 0,
#  'myraculous': 0,
#  'deseruers.': 0,
#  'Vnspeake': 0,
#  'Etext': 0,
#  'Thumbe,': 0,
#  'furbusht': 0,
#  'meeting': 0,
#  '*END*THE': 0,
#  'doubtfull': 0,
#  'mad:': 0,
#  'betweene': 0,
#  'feele': 0,
#  'God,': 0,
#  'waite': 0,
#  'Sexta.': 0,
#  'besides': 0,
#  'flower,': 0,
#  'Health': 0,
#  'Riddles,': 0,
#  'hath': 0,
#  'Reed': 0,
#  "murther'd": 0,
#  'perillous': 0,
#  'humbly': 0,
#  'give': 0,
#  'deed?': 0,
#  'predominant,': 0,
#  "displac'd": 0,
#  'onely:': 0,
#  'welcome,': 0,
#  'lips.': 0,
#  'selues': 0,
#  'leaues': 0,
#  'Story': 0,
#  'sweat': 0,
#  'editing': 0,
#  'yawning': 0,
#  'Sea': 0,
#  'New': 0,
#  'Hose:': 0,
#  "Heere's": 0,
#  'Non-pareill': 0,
#  'redoubled': 0,
#  'older,': 0,
#  'Knock,': 0,
#  'Special': 0,
#  'OR': 0,
#  'conclusion,': 0,
#  "perfect'st": 0,
#  'Rebell,': 0,
#  '(at': 0,
#  'neuer': 0,
#  "esteem'st": 0,
#  "cry'd": 0,
#  'Belzebub?': 0,
#  'KIND,': 0,
#  'Owle:': 0,
#  'above.': 0,
#  'swoope?': 0,
#  'aboue': 0,
#  'meet,': 0,
#  'Killing': 0,
#  'Gutenberg/CMU":': 0,
#  'their': 0,
#  'last': 0,
#  'womanly': 0,
#  'beest': 0,
#  'cost,': 0,
#  'stolne': 0,
#  'bleeding,': 0,
#  'else,': 0,
#  'deeds': 0,
#  'USE': 0,
#  'Root?': 0,
#  'tumble': 0,
#  'cheere': 0,
#  'sight:': 0,
#  'makes': 0,
#  'Babe': 0,
#  'Life,': 0,
#  'Table': 0,
#  'buriall': 0,
#  'fell.': 0,
#  'first.': 0,
#  'impresse,': 0,
#  'extent': 0,
#  'morrow': 0,
#  'Metaphysicall': 0,
#  'off;': 0,
#  'term': 0,
#  'Owle': 0,
#  'beene': 0,
#  'Though': 0,
#  ...}

# %%
# Iterate through the text of Macbeth
i = 0
for word in macbeth_words:
    # Update word counts
    macbeth_words_dict[word] += 1

macbeth_words_dict
# Out:
# {'Demand': 1,
#  'seuen': 1,
#  'Cases,': 1,
#  'eare.': 1,
#  'Neptunes': 1,
#  'fighting.': 1,
#  'direfull': 1,
#  'Meeting': 1,
#  'Art': 4,
#  'Angels': 1,
#  'Witchcraft': 1,
#  'What,': 4,
#  'commend': 2,
#  'there.': 1,
#  'quell': 1,
#  'require': 2,
#  'sweeter': 1,
#  'There': 12,
#  '&': 18,
#  'Performe': 1,
#  'Whole': 1,
#  'brother?': 1,
#  'fairer': 1,
#  'periodic)': 1,
#  'Warre': 2,
#  'dare': 11,
#  'murky.': 1,
#  'Whispers': 1,
#  'What': 58,
#  'mget': 1,
#  'thousands.': 1,
#  'Dogs,': 1,
#  'plays.': 1,
#  'users.': 1,
#  'Churches:': 1,
#  'conceiue,': 1,
#  'meane?': 1,
#  "stay'd": 1,
#  'estate': 1,
#  'Temple-haunting': 1,
#  'Scoena': 1,
#  'Seywards': 2,
#  "for't.": 1,
#  'can': 27,
#  'eyes?': 1,
#  'together?': 1,
#  'owe': 1,
#  'wooingly': 1,
#  'further,': 4,
#  'production,': 1,
#  'Feuer,': 1,
#  'High': 1,
#  'funding;': 1,
#  'lyes': 4,
#  'Flowers': 1,
#  'within.': 7,
#  'sleeping,': 1,
#  'call.': 1,
#  "there's": 5,
#  'author': 2,
#  'ore-leapes': 1,
#  'keene': 2,
#  'day?': 1,
#  'offended:': 1,
#  'Assassination': 1,
#  'timely': 2,
#  'rarer': 1,
#  'be': 133,
#  "Prey's": 1,
#  'rightly': 1,
#  'where': 14,
#  'Trifles,': 1,
#  'Seruants': 2,
#  'caveat.': 1,
#  'meeke;': 1,
#  'bound': 1,
#  'prouokes': 1,
#  'drops': 1,
#  'leauy': 1,
#  'Syue': 1,
#  'taught,': 1,
#  'name?': 1,
#  'Nay,': 1,
#  'accust,': 1,
#  'aduantage': 1,
#  'Their': 5,
#  'Venom': 2,
#  'bed,': 4,
#  'paines,': 2,
#  "Master's": 1,
#  'continue': 1,
#  'browser': 2,
#  'wastfull': 1,
#  'MAY': 2,
#  'Letters': 1,
#  'preserue': 1,
#  'rellish': 1,
#  'Moone': 2,
#  'ouerthrowne': 1,
#  "Turn'd": 1,
#  'concerne': 1,
#  'Strangers': 1,
#  'House?': 2,
#  'Gorgon.': 1,
#  'Drum': 4,
#  'Blinde-wormes': 1,
#  'Imaginings:': 1,
#  'Comes': 2,
#  'works.': 1,
#  'Say,': 2,
#  'Murther,': 3,
#  'Ecclipse:': 1,
#  'Primus.': 1,
#  'Brest,': 1,
#  'Hearts,': 1,
#  'Childhood,': 1,
#  'States,': 1,
#  'words': 5,
#  'etext': 17,
#  'noyse': 1,
#  'contributions': 1,
#  'well,': 10,
#  'password:': 1,
#  'signe,': 1,
#  'pace': 1,
#  'And': 169,
#  'thanks': 2,
#  'yellow': 1,
#  'those': 22,
#  '********************The': 2,
#  'care:': 1,
#  'endure': 1,
#  'Pertaines': 1,
#  'plain': 2,
#  'speech,': 1,
#  'distance': 1,
#  'Summer,': 1,
#  'Verity,': 1,
#  'woman;': 1,
#  "chanc'd:": 1,
#  'links;': 1,
#  'swolne': 1,
#  'thou,': 1,
#  'According': 2,
#  'Coward': 1,
#  'Wise,': 1,
#  'wife:': 1,
#  'haunt': 1,
#  'property': 1,
#  'runs': 1,
#  'Vsing': 1,
#  'Conspirers': 1,
#  'viewing': 1,
#  'Wake': 1,
#  'yong,': 1,
#  'This': 34,
#  'Make': 5,
#  'mee': 2,
#  'cheekes': 1,
#  'Largesse': 1,
#  'INDEMNITY': 1,
#  "Cow'd": 1,
#  'away': 6,
#  'wants': 2,
#  'poorely': 1,
#  'graue': 1,
#  'Darknesse': 2,
#  'nine': 2,
#  'vp': 20,
#  'year.': 1,
#  'verities': 1,
#  'right:': 1,
#  'Diuine,': 1,
#  'may': 42,
#  'POSSIBILITY': 1,
#  'Lords': 1,
#  'corporall': 1,
#  'Seemes': 1,
#  '[xxxxx10x.xxx]': 1,
#  'Rankes,': 1,
#  'stealthy': 1,
#  'Lady,': 4,
#  '*These': 1,
#  'ye': 3,
#  'Madam': 1,
#  'vntill': 1,
#  'Maggot': 1,
#  'content': 1,
#  'indeed': 3,
#  'Worlds': 1,
#  'chiefe': 1,
#  'Battlements': 1,
#  'set': 8,
#  "charg'd": 2,
#  'Custome:': 1,
#  'Consider': 1,
#  'Hart,': 1,
#  'Thriftlesse': 1,
#  'Feast,': 2,
#  'Michael': 4,
#  'This,': 1,
#  'dead': 4,
#  'running': 1,
#  'we,': 1,
#  'Norwayes': 1,
#  'Image:': 1,
#  'distribution': 1,
#  'Water-Rugs,': 1,
#  'also': 4,
#  'making:': 1,
#  'true?': 1,
#  'True,': 1,
#  'Children': 3,
#  'doing': 2,
#  'is.': 2,
#  'Kinsmen,': 1,
#  'Heark,': 1,
#  'Traueller': 1,
#  "Ditch-deliuer'd": 1,
#  'son': 1,
#  'eate': 3,
#  'strooke': 1,
#  'drinke,': 1,
#  'pale,': 1,
#  'what': 45,
#  'So': 28,
#  'weightie': 1,
#  'asleepe:': 1,
#  'Colmekill,': 1,
#  "vpon't,": 1,
#  "Nought's": 1,
#  'him;': 3,
#  'given': 1,
#  'any': 22,
#  'data,': 1,
#  'Butcher,': 1,
#  'read': 4,
#  'neyther': 2,
#  'Against': 5,
#  'hard': 3,
#  'solicites': 1,
#  'inuite,': 1,
#  'imperfect': 1,
#  'hands': 3,
#  'variety': 1,
#  'rid': 1,
#  'bad': 4,
#  "make's": 1,
#  "ha's?": 1,
#  'out': 19,
#  'One': 3,
#  'heere:': 2,
#  'sort': 1,
#  'which,': 1,
#  'Army,': 1,
#  'eye': 1,
#  'Fye,': 1,
#  'cleane?': 1,
#  'Despite': 1,
#  'At': 8,
#  'like': 33,
#  'keepes': 3,
#  'doe?': 1,
#  'Macduffe,': 6,
#  'cries': 1,
#  'software,': 2,
#  'supplyes': 1,
#  'file:': 1,
#  'legally': 1,
#  'tels': 1,
#  "awak'd": 1,
#  'broad,': 2,
#  'Feasts,': 1,
#  "Thou'lt": 1,
#  'expends': 1,
#  'happy': 2,
#  'Out-run': 1,
#  'liue,': 2,
#  'copy': 7,
#  'Malcolme,': 8,
#  'implied': 1,
#  'sences': 2,
#  'report': 5,
#  'performe': 3,
#  'hell': 1,
#  'Peale,': 1,
#  'Supper.': 1,
#  'MONEY': 1,
#  'please': 11,
#  'sight,': 4,
#  'cleaue': 2,
#  'traines,': 1,
#  'Hoast,': 1,
#  'thou?': 1,
#  'filling': 1,
#  'Epicures,': 1,
#  'Feat.': 1,
#  'further.': 1,
#  '[Etext': 1,
#  'Royalty': 1,
#  'Powres': 1,
#  'lacke': 3,
#  'present': 4,
#  'domain': 2,
#  'Venture': 1,
#  'Know,': 1,
#  'Greyhounds,': 1,
#  'trying': 1,
#  'brought': 2,
#  'calculate': 1,
#  'quit': 1,
#  'Acting': 1,
#  'touch.': 1,
#  'Threescore': 1,
#  'spoke,': 1,
#  'fresh': 1,
#  "vap'rous": 1,
#  'did:': 1,
#  'population,': 1,
#  "smoak'd": 1,
#  'indicate': 2,
#  'will.': 2,
#  'Ha,': 1,
#  'Everything': 1,
#  'House:': 2,
#  'held': 1,
#  'sprights,': 1,
#  'Drumme': 2,
#  'blames': 1,
#  'proud,': 1,
#  'wayes': 1,
#  'Wisdome,': 1,
#  'assaileable,': 1,
#  'Scale': 1,
#  'Hircan': 1,
#  'worthy': 13,
#  'chance': 1,
#  '"Defects".': 1,
#  'Fleans,': 2,
#  'smeare': 1,
#  'contacting': 1,
#  'Heart': 5,
#  'Shakes': 1,
#  'woe,': 1,
#  'troubled': 2,
#  'rauishing': 1,
#  'That': 80,
#  'Gulfe': 1,
#  'Stablenesse,': 1,
#  'againe?': 2,
#  'guild': 1,
#  'wayle': 1,
#  'Beare,': 1,
#  'After': 2,
#  'Disasters,': 1,
#  'purposes': 1,
#  'fitfull': 1,
#  'UNDER': 2,
#  "Shee'le": 1,
#  'others': 2,
#  'piece': 1,
#  'States': 2,
#  'Holy': 1,
#  'Example': 1,
#  'Beauteous,': 1,
#  'Takes': 1,
#  'large': 2,
#  'clutch': 1,
#  "mark'd": 1,
#  'multitudinous': 1,
#  'free:': 1,
#  "'Gainst": 2,
#  'Mankinde': 1,
#  '"cliche".': 1,
#  'meane:': 1,
#  'Heere,': 1,
#  'durst': 1,
#  'Dames': 1,
#  'cryes,': 1,
#  "arriu'd": 1,
#  'several': 2,
#  'Who,': 1,
#  'dread': 1,
#  'perfect': 2,
#  'composition:': 1,
#  'Soris?': 1,
#  'on,': 3,
#  'paid': 5,
#  '"public': 1,
#  'hypertext': 2,
#  'Ingratitude': 1,
#  'worst': 3,
#  'knowings': 1,
#  '2001.': 1,
#  'done.': 1,
#  'sorely': 1,
#  'PUBLIC': 2,
#  'part?': 1,
#  'M.': 1,
#  'greefe': 1,
#  'close': 4,
#  'angry': 1,
#  'Farrow:': 1,
#  '"AS-IS".': 1,
#  'Vice': 1,
#  'sometime,': 1,
#  'Deny': 1,
#  'Light,': 1,
#  'voyce': 1,
#  'aye': 1,
#  'Syw.': 1,
#  'Norway': 1,
#  'particulars': 1,
#  'Murtherers.': 3,
#  'Signifying': 1,
#  'Vprore': 1,
#  'Barnardo.': 1,
#  'owne': 15,
#  'Lid:': 1,
#  'Attend': 3,
#  'Doctor.': 2,
#  'dead,': 7,
#  'Mile': 1,
#  'PUNITIVE': 1,
#  'Wherefore': 2,
#  'failed]': 1,
#  'Witches,': 1,
#  'Spightfull,': 1,
#  'efforts,': 1,
#  'Hell-broth,': 1,
#  'againe:': 3,
#  'Trust.': 1,
#  "fayl'd": 1,
#  'cling': 2,
#  'paine:': 1,
#  'hold': 7,
#  'vs?': 3,
#  'stirring?': 1,
#  'Before': 2,
#  'Prince': 2,
#  'Graces': 3,
#  'harts': 1,
#  'powre': 4,
#  '[3]': 2,
#  'Graces,': 1,
#  'choake': 1,
#  'as': 67,
#  'Fume,': 1,
#  "prepar'd.": 1,
#  'poure': 1,
#  'sight?': 1,
#  'effects': 1,
#  'conjoined': 1,
#  'virus,': 1,
#  'Front,': 1,
#  '.set': 1,
#  "ow'd,": 1,
#  'digestion': 1,
#  '"w"\'s,': 1,
#  'Trumpet': 1,
#  'Childe.': 1,
#  'Braggart': 1,
#  'come.': 2,
#  'LIABILITY,': 1,
#  'Professe,': 1,
#  'Drinke,': 1,
#  'safetie.': 1,
#  'came': 4,
#  '[to': 4,
#  'hideous': 1,
#  'liue': 6,
#  'him.': 7,
#  'mine': 19,
#  'flattering': 1,
#  'vpon': 47,
#  'winde.': 1,
#  'Walke.': 1,
#  'So.': 1,
#  'Homage,': 1,
#  'burne': 1,
#  'bleed': 1,
#  'Who': 21,
#  'distance,': 1,
#  'Theefe': 1,
#  'Accounted': 1,
#  'Murderer.': 1,
#  'guilt': 1,
#  'stone,': 1,
#  'strangers': 1,
#  'nor': 21,
#  'loued': 1,
#  'Rancours': 1,
#  'vnsure': 1,
#  'later': 1,
#  'intent,': 1,
#  'Wine': 1,
#  "for't": 1,
#  'black': 3,
#  'Those': 6,
#  'horrid': 3,
#  'Attendants.': 5,
#  'Father?': 3,
#  'Of': 22,
#  'Lad.': 3,
#  'Messenger': 2,
#  'enough:': 4,
#  'Arme,': 3,
#  'Giuen': 1,
#  'Fortitude,': 1,
#  'ouer-bold,': 1,
#  'I:': 1,
#  'Cousins,': 1,
#  'burne,': 3,
#  'thinke,': 2,
#  "S's": 1,
#  'cleare:': 1,
#  'Scone.': 1,
#  'slab.': 1,
#  'Hand:': 1,
#  'shalt': 6,
#  'Spirits': 3,
#  '**Etexts': 1,
#  '(well': 1,
#  'changes,': 1,
#  'Hostesse.': 1,
#  'Destinie.': 1,
#  '100,000,000': 1,
#  'Tyranny:': 1,
#  'sutes': 1,
#  'STRICT': 1,
#  'Peace': 1,
#  'Began': 1,
#  "inform'd": 1,
#  'Forrest,': 1,
#  'quickly': 2,
#  'edition.': 1,
#  'DOMAIN': 2,
#  "vs'd": 2,
#  'Already': 1,
#  'Neither': 1,
#  'grow,': 2,
#  '[1]': 3,
#  'furious,': 1,
#  'Minde': 1,
#  'smacking': 1,
#  'Lye': 1,
#  'Crowne,': 2,
#  'thankes': 1,
#  'top-full': 1,
#  'Poyson,': 1,
#  'meane,': 1,
#  'alowd': 1,
#  'Donal.': 2,
#  'harrold': 1,
#  'Craues': 1,
#  'rather': 7,
#  'PRINT!': 1,
#  'prairienet.org,': 1,
#  'Sisters:': 1,
#  'Deuill': 2,
#  'witnest': 1,
#  'Blacke': 1,
#  'Wayting': 1,
#  'troubles:': 1,
#  "is't": 5,
#  'Faces': 3,
#  'vp:': 2,
#  'Iewels,': 1,
#  'WHAT': 1,
#  'cost': 1,
#  'extreme': 1,
#  "talk'st?": 1,
#  'Braine?': 1,
#  'Banquo.': 6,
#  'sighes,': 1,
#  'auoyded': 1,
#  'withall:': 1,
#  'Chance': 2,
#  'age,': 1,
#  'Macduffe.': 6,
#  'Watch,': 1,
#  'Lees': 1,
#  'recommends': 1,
#  'Day.': 2,
#  'mile:': 1,
#  'own': 1,
#  'Rosse.': 40,
#  'Northumberland,': 1,
#  'shade,': 1,
#  'clipt': 1,
#  'ill?': 1,
#  'resembled': 1,
#  'pit': 1,
#  "ne're": 2,
#  'Meet': 1,
#  'How': 20,
#  'Into': 3,
#  'withall': 1,
#  'whose': 5,
#  'Dunsinane': 3,
#  'Instruments': 1,
#  'here:': 1,
#  'Blessing,': 1,
#  'fly': 2,
#  'path': 1,
#  'houre:': 1,
#  'Commencing': 1,
#  'finger': 1,
#  'repent': 1,
#  'howle,': 1,
#  'pleasant': 1,
#  'Leade': 1,
#  "speak'st": 2,
#  'hat': 1,
#  'happyer': 1,
#  'Seruants;': 1,
#  'goodnight': 1,
#  'Shake': 2,
#  'cures,': 1,
#  'intended': 2,
#  'rest?': 1,
#  'pole,': 1,
#  'Fee-griefe': 1,
#  'twice': 1,
#  'death;': 1,
#  'bend': 1,
#  'Lord,': 17,
#  'Wisedome': 1,
#  '"small': 1,
#  'Goes': 2,
#  'Mawes': 1,
#  'stooles.': 1,
#  'Physitian:': 1,
#  'Trees': 2,
#  'saide': 1,
#  'Eagles;': 1,
#  'Patch?': 1,
#  'included.': 1,
#  'moue': 2,
#  'afraid': 1,
#  'loue': 5,
#  "deny't.": 1,
#  'countenance': 1,
#  'fought': 1,
#  'much:': 1,
#  "ly'st": 1,
#  'devised': 1,
#  'seeking': 1,
#  'same': 1,
#  'Mess.': 2,
#  'run.': 1,
#  'Braine': 1,
#  'pretend?': 1,
#  'ae.': 1,
#  'feare.': 2,
#  'nearly': 1,
#  'Court?': 1,
#  'Traitor': 1,
#  'Soule,': 2,
#  'Father': 8,
#  'damages,': 2,
#  'Coigne': 1,
#  'Mortalitie:': 1,
#  'yet': 45,
#  'broke': 3,
#  'stopt': 1,
#  'Horse:': 1,
#  'click,': 1,
#  'slope': 1,
#  'sorryest': 1,
#  'David': 1,
#  'users,': 1,
#  'substances,': 1,
#  'Weale:': 1,
#  'defect,': 1,
#  'notes': 1,
#  'there?': 6,
#  'Had': 5,
#  'an': 32,
#  'bathe': 1,
#  'heat': 1,
#  'ignorant': 2,
#  'Neuer': 1,
#  'Battell.': 1,
#  'empty': 1,
#  'Mal.': 25,
#  'Remorse,': 1,
#  'Scruples,': 1,
#  'seeme': 7,
#  'wayes:': 1,
#  'chafes,': 1,
#  'begge': 1,
#  'pricking': 1,
#  "'twer": 1,
#  'true': 3,
#  'of.': 2,
#  'easie.': 1,
#  'Act': 1,
#  'Soundly': 1,
#  'Confusion': 1,
#  'yeeld': 4,
#  'wrencht': 1,
#  'Sing': 1,
#  'gaue': 2,
#  'grace': 2,
#  'Particular': 1,
#  'Thoughts': 2,
#  'dir': 1,
#  'Hill': 2,
#  '-': 1,
#  'sinkes': 2,
#  'subtle,': 1,
#  'vnlineall': 1,
#  'Boughes.': 1,
#  'prepared': 2,
#  'Mother,': 2,
#  'Erre': 1,
#  'powrefull': 1,
#  'Rest': 1,
#  'beare': 8,
#  'Noblenesse,': 1,
#  'Kings': 2,
#  'cut': 1,
#  'practice': 1,
#  'goal': 1,
#  "obseru'd": 1,
#  'Carnegie-': 1,
#  "King's": 1,
#  'Hye': 1,
#  'herein:': 1,
#  'did,': 1,
#  'Summers': 1,
#  "kind'st": 1,
#  'regard': 1,
#  'health': 3,
#  'laue': 1,
#  'rise': 4,
#  'Lust,': 1,
#  'Vntimely': 1,
#  'behold:': 1,
#  'hours': 1,
#  'peace': 1,
#  'Closset,': 1,
#  'analyzed,': 1,
#  'Liege,': 2,
#  'flowne': 1,
#  "dy'de": 2,
#  'enjoy': 1,
#  'Fiend-like': 1,
#  'profits': 1,
#  'manner.': 1,
#  'ae': 1,
#  'Could': 1,
#  'Gummes,': 1,
#  'Marble,': 1,
#  'darefull,': 1,
#  'Starres,': 1,
#  'arbitrate,': 1,
#  'profound,': 1,
#  'have': 19,
#  'Vnkle': 1,
#  'meanes': 2,
#  'doubly': 1,
#  'subiect': 1,
#  'that:': 3,
#  'Not': 10,
#  'weyward': 3,
#  'Didst': 1,
#  'deerest': 1,
#  'new': 10,
#  'Knocking': 1,
#  'Doubtfull': 1,
#  "Can'st": 1,
#  '***The': 1,
#  'Seyton,': 4,
#  'worth,': 1,
#  'Temple,': 1,
#  'Hayle': 3,
#  'light': 1,
#  'Light?': 1,
#  'ill:': 1,
#  'swells:': 1,
#  'statement': 2,
#  'euer': 8,
#  'Barlet': 1,
#  'Maiestie?': 1,
#  "may'st": 3,
#  'giues': 3,
#  'Bloody,': 1,
#  'dauntlesse': 1,
#  'warranties': 1,
#  'Sent': 1,
#  'defective': 1,
#  'domestique,': 1,
#  'cloud,': 1,
#  'vnaccompanied,': 1,
#  'Geese': 1,
#  'who': 21,
#  'Treatise': 1,
#  "'twould": 1,
#  'anon': 3,
#  'speake,': 2,
#  'Beetle,': 1,
#  'session:': 1,
#  'WARRANTIES': 2,
#  'swelling': 1,
#  'been': 6,
#  'Passion,': 1,
#  'Honors,': 1,
#  'Actus': 5,
#  'mirrors': 1,
#  'Lookes,': 1,
#  'him:': 3,
#  'Cosin': 1,
#  'open:': 1,
#  'abroad:': 1,
#  'safely': 1,
#  'Foggy': 1,
#  'almost': 5,
#  'worse': 3,
#  "could'st": 1,
#  'stoole': 1,
#  'pine': 1,
#  'mould,': 1,
#  'afternoone?': 1,
#  'Shipwracking': 1,
#  "fear'd.": 1,
#  'hit.': 1,
#  'costs': 1,
#  'dare,': 1,
#  "brew'd": 1,
#  'alternatively': 2,
#  'Dunsinane.': 1,
#  'Yes,': 2,
#  'blacke,': 1,
#  'more,': 4,
#  'Rosse': 3,
#  'Eyes.': 2,
#  'Fiffe,': 1,
#  'Peeres': 1,
#  'fauor,': 1,
#  'Space': 1,
#  'within': 10,
#  'Addage': 1,
#  'saw,': 1,
#  'Snake,': 2,
#  'Notes:': 2,
#  'woman': 5,
#  'vertue,': 1,
#  'Whom': 4,
#  'print!"': 1,
#  'once.': 1,
#  'by': 55,
#  'hearty': 1,
#  'hisse': 1,
#  'REMEDIES': 1,
#  'solemne': 1,
#  'stopt,': 1,
#  'prouoker': 1,
#  'stand': 7,
#  'wicked': 2,
#  'speech:': 1,
#  'Gin': 1,
#  'gate:': 1,
#  'Grace.': 1,
#  'Gouts': 1,
#  'Disease': 1,
#  "Project's": 2,
#  'THE': 3,
#  'Quarry': 2,
#  'pale:': 1,
#  "Med'cines": 1,
#  'Sleep': 1,
#  'Cooz,': 1,
#  'day': 10,
#  'selection': 1,
#  'See': 3,
#  '2000+': 1,
#  'reading': 2,
#  'together,': 2,
#  'hurt': 1,
#  'hands:': 2,
#  'strangely': 2,
#  'changed': 3,
#  'Another': 2,
#  'Meete': 1,
#  'grant': 1,
#  'steales': 1,
#  "watch'd": 1,
#  'charge': 2,
#  'doe': 26,
#  "confirm'd": 2,
#  'A': 28,
#  "Promis'd": 1,
#  'roote': 1,
#  'But': 61,
#  'leysure,': 1,
#  'incarnardine,': 1,
#  'Was': 13,
#  'rowse.': 1,
#  'Warders': 1,
#  'Adde': 1,
#  'Witch,': 1,
#  'entrance:': 1,
#  'Mindes': 1,
#  'selfe-comparisons,': 1,
#  'Stay': 1,
#  'myraculous': 1,
#  'deseruers.': 1,
#  'Vnspeake': 1,
#  'Etext': 5,
#  'Thumbe,': 1,
#  'furbusht': 1,
#  'meeting': 2,
#  '*END*THE': 1,
#  'doubtfull': 1,
#  'mad:': 1,
#  'betweene': 2,
#  'feele': 4,
#  'God,': 1,
#  'waite': 1,
#  'Sexta.': 3,
#  'besides': 1,
#  'flower,': 1,
#  'Health': 1,
#  'Riddles,': 1,
#  'hath': 37,
#  'Reed': 1,
#  "murther'd": 4,
#  'perillous': 1,
#  'humbly': 1,
#  'give': 3,
#  'deed?': 1,
#  'predominant,': 1,
#  "displac'd": 1,
#  'onely:': 2,
#  'welcome,': 1,
#  'lips.': 1,
#  'selues': 2,
#  'leaues': 2,
#  'Story': 1,
#  'sweat': 1,
#  'editing': 1,
#  'yawning': 1,
#  'Sea': 3,
#  'New': 3,
#  'Hose:': 1,
#  "Heere's": 2,
#  'Non-pareill': 1,
#  'redoubled': 1,
#  'older,': 1,
#  'Knock,': 6,
#  'Special': 1,
#  'OR': 10,
#  'conclusion,': 1,
#  "perfect'st": 1,
#  'Rebell,': 1,
#  '(at': 1,
#  'neuer': 11,
#  "esteem'st": 1,
#  "cry'd": 2,
#  'Belzebub?': 1,
#  'KIND,': 1,
#  'Owle:': 1,
#  'above.': 1,
#  'swoope?': 1,
#  'aboue': 2,
#  'meet,': 1,
#  'Killing': 1,
#  'Gutenberg/CMU":': 1,
#  'their': 57,
#  'last': 7,
#  'womanly': 1,
#  'beest': 1,
#  'cost,': 1,
#  'stolne': 1,
#  'bleeding,': 1,
#  'else,': 1,
#  'deeds': 2,
#  'USE': 1,
#  'Root?': 1,
#  'tumble': 1,
#  'cheere': 3,
#  'sight:': 1,
#  'makes': 4,
#  'Babe': 1,
#  'Life,': 5,
#  'Table': 1,
#  'buriall': 1,
#  'fell.': 2,
#  'first.': 1,
#  'impresse,': 1,
#  'extent': 1,
#  'morrow': 3,
#  'Metaphysicall': 1,
#  'off;': 1,
#  'term': 1,
#  'Owle': 3,
#  'beene': 9,
#  'Though': 11,
#  ...}

# %%
#Checks
just_counts = sum(list(macbeth_words_dict.values()))
just_counts
# Out:
# 20347

# %%
listy = list(macbeth_words_dict.keys())
listy[:20]
# Out:
# ['Demand',
#  'seuen',
#  'Cases,',
#  'eare.',
#  'Neptunes',
#  'fighting.',
#  'direfull',
#  'Meeting',
#  'Art',
#  'Angels',
#  'Witchcraft',
#  'What,',
#  'commend',
#  'there.',
#  'quell',
#  'require',
#  'sweeter',
#  'There',
#  '&',
#  'Performe']

# %%
# Create Bar Graph
import matplotlib.pyplot as plt
# %matplotlib inline

# Set a figure size
plt.figure(figsize=(10,6))

# Plot vertical bars of fixed width by passing x and y values to .bar() function 
plt.bar( list(macbeth_words_dict.keys())[:20], macbeth_words_dict.values() )

# Give a title to the bar graph
plt.title( "Macbeth Word Counts." )

# Output the final plot
plt.show()
# Out:
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-6-8880ca1f9808> in <module>()
#      13
#      14 # Output the final plot
# ---> 15 plt.show()
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/matplotlib/pyplot.py in show(*args, **kw)
#     252     """
#     253     global _show
# --> 254     return _show(*args, **kw)
#     255
#     256
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     296             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297         else:
# --> 298             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299             if not format_dict:
#     300                 # nothing to display (e.g. _ipython_display_ took over)
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-9> in __call__(self, obj)
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     239
#     240     if 'png' in formats:
# --> 241         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     242     if 'retina' in formats or 'png2x' in formats:
#     243         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     123
#     124     bytes_io = BytesIO()
# --> 125     fig.canvas.print_figure(bytes_io, **kw)
#     126     data = bytes_io.getvalue()
#     127     if fmt == 'svg':
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2051                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#    2052                     bbox_inches = self.figure.get_tightbbox(renderer,
# -> 2053                             bbox_extra_artists=bbox_artists)
#    2054                     pad = kwargs.pop("pad_inches", None)
#    2055                     if pad is None:
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/matplotlib/figure.py in get_tightbbox(self, renderer, bbox_extra_artists)
#    2268
#    2269         for a in artists:
# -> 2270             bbox = a.get_tightbbox(renderer)
#    2271             if bbox is not None and (bbox.width != 0 or bbox.height != 0):
#    2272                 bb.append(bbox)
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/matplotlib/axes/_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists)
#    4394
#    4395         for a in bbox_artists:
# -> 4396             bbox = a.get_tightbbox(renderer)
#    4397             if (bbox is not None and
#    4398                     (bbox.width != 0 or bbox.height != 0) and
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/matplotlib/axis.py in get_tightbbox(self, renderer)
#    1138             return
#    1139
# -> 1140         ticks_to_draw = self._update_ticks(renderer)
#    1141
#    1142         self._update_label_position(renderer)
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/matplotlib/axis.py in _update_ticks(self, renderer)
#    1021
#    1022         interval = self.get_view_interval()
# -> 1023         tick_tups = list(self.iter_ticks())  # iter_ticks calls the locator
#    1024         if self._smart_bounds and tick_tups:
#    1025             # handle inverted limits
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/matplotlib/axis.py in iter_ticks(self)
#     969         self.major.formatter.set_locs(majorLocs)
#     970         majorLabels = [self.major.formatter(val, i)
# --> 971                        for i, val in enumerate(majorLocs)]
#     972
#     973         minorLocs = self.minor.locator()
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/matplotlib/axis.py in <listcomp>(.0)
#     969         self.major.formatter.set_locs(majorLocs)
#     970         majorLabels = [self.major.formatter(val, i)
# --> 971                        for i, val in enumerate(majorLocs)]
#     972
#     973         minorLocs = self.minor.locator()
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/matplotlib/category.py in __call__(self, x, pos)
#     140             return ""
#     141         r_mapping = {v: StrCategoryFormatter._text(k)
# --> 142                      for k, v in self._units.items()}
#     143         return r_mapping.get(int(np.round(x)), '')
#     144
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/matplotlib/category.py in <dictcomp>(.0)
#     140             return ""
#     141         r_mapping = {v: StrCategoryFormatter._text(k)
# --> 142                      for k, v in self._units.items()}
#     143         return r_mapping.get(int(np.round(x)), '')
#     144
#
# KeyboardInterrupt:

# %%
# Include descriptive titles and labels

# %% [markdown]
# ### Level Up (Optional)
# This project should take you about an hour and a half to complete. If you're done much more quickly than that and are not behind in the course, feel free to deepen your knowledge by completing any or all of the following tasks until you run out of time:
# * Create a list of top characters by mentions of their names
# * Split the text by which character is talking
# * Create sub graphs of the most common words by character
# * Reduce the string to the text of the play itself. (Remove any initial notes, forward, introduction, appendix, etc.)
# * Come up with some other fun analyses of the text!

# %% [markdown]
# ## Summary
# Congratulations! You've got some extra practice combining various data types into useful programming patterns and done an intitial analysis of a classic text!
